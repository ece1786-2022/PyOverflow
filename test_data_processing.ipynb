# %%
# import csv files from data/test_data
import pandas as pd

data = pd.read_csv('data/Test/regex.csv')
data.head()
# Out:
#         Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  2718196           1         2718268.0       NaN  2010-04-27 01:34:29
# 1  2723485           1               NaN       NaN  2010-04-27 17:30:05
# 2  5088821           1         5089070.0       NaN  2011-02-23 09:03:43
# 3  8121789           1         8121808.0       NaN  2011-11-14 12:45:31
# 4  9815095           1         9815129.0       NaN  2012-03-22 01:05:04
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN     25      48966
# 1           NaN      1        110
# 2           NaN      1       3720
# 3           NaN      0        632
# 4           NaN      4      18824
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I needed to strip the Chinese out of a bunc...      27462.0  ...
# 1  <p>I made a program in Python and now I whant ...     316758.0  ...
# 2  <p>I have a string (with multiple lines) which...     602691.0  ...
# 3  <p>In my python code i want to pattern match a...    1044140.0  ...
# 4  <p>I use the regex [,;\s]+ to split a comma, s...     433352.0  ...
#
#           LastEditDate     LastActivityDate  \
# 0  2012-05-05 03:01:20  2019-07-29 16:47:32
# 1                  NaN  2010-04-27 17:42:39
# 2  2011-02-23 09:06:47  2011-02-23 10:16:35
# 3                  NaN  2011-11-14 13:03:24
# 4  2012-03-22 01:10:50  2012-03-22 01:26:16
#
#                                                Title                     Tags  \
# 0  Find all Chinese text in a string using Python...     <python><regex><cjk>
# 1                             Python Regex To VB.net  <python><vb.net><regex>
# 2  how to match lines between pattern using re mo...          <python><regex>
# 3  Pattern Match a string for atleast two consecu...          <python><regex>
# 4  split a comma, space, or semicolon separated s...          <python><regex>
#
#   AnswerCount CommentCount FavoriteCount  ClosedDate   CommunityOwnedDate  \
# 0           2            2           0.0         NaN  2010-04-27 01:34:29
# 1           1            0           NaN         NaN                  NaN
# 2           4            0           NaN         NaN                  NaN
# 3           3            3           NaN         NaN                  NaN
# 4           3            0           NaN         NaN                  NaN
#
#    ContentLicense
# 0    CC BY-SA 3.0
# 1    CC BY-SA 2.5
# 2    CC BY-SA 2.5
# 3    CC BY-SA 3.0
# 4    CC BY-SA 3.0
#
# [5 rows x 23 columns]

# %%
# remove all the columns except for id, body, title and tags
data = data[['Id', 'Body', 'Title', 'Tags']]
data.head()
# Out:
#         Id                                               Body  \
# 0  2718196  <p>I needed to strip the Chinese out of a bunc...
# 1  2723485  <p>I made a program in Python and now I whant ...
# 2  5088821  <p>I have a string (with multiple lines) which...
# 3  8121789  <p>In my python code i want to pattern match a...
# 4  9815095  <p>I use the regex [,;\s]+ to split a comma, s...
#
#                                                Title                     Tags
# 0  Find all Chinese text in a string using Python...     <python><regex><cjk>
# 1                             Python Regex To VB.net  <python><vb.net><regex>
# 2  how to match lines between pattern using re mo...          <python><regex>
# 3  Pattern Match a string for atleast two consecu...          <python><regex>
# 4  split a comma, space, or semicolon separated s...          <python><regex>

# %%
# remove everything in between <code> and </code> tags
# remove all the html tags
import re
def remove_code_tags(text):
	    return re.sub(r'<code>.*?</code>', '', text, flags=re.DOTALL)

data['Body'] = data['Body'].apply(remove_code_tags)
data.head()
# Out:
#         Id                                               Body  \
# 0  2718196  <p>I needed to strip the Chinese out of a bunc...
# 1  2723485  <p>I made a program in Python and now I whant ...
# 2  5088821  <p>I have a string (with multiple lines) which...
# 3  8121789  <p>In my python code i want to pattern match a...
# 4  9815095  <p>I use the regex [,;\s]+ to split a comma, s...
#
#                                                Title                     Tags
# 0  Find all Chinese text in a string using Python...     <python><regex><cjk>
# 1                             Python Regex To VB.net  <python><vb.net><regex>
# 2  how to match lines between pattern using re mo...          <python><regex>
# 3  Pattern Match a string for atleast two consecu...          <python><regex>
# 4  split a comma, space, or semicolon separated s...          <python><regex>

# %%
data['Body'] = data['Body'].str.replace('<.*?>', '')

# remove all /n, /t, /r, /u characters
data['Body'] = data['Body'].str.replace(r'[\n\t\r]', ' ')

# %%
data.head()
# Out:
#         Id                                               Body  \
# 0  2718196  I needed to strip the Chinese out of a bunch o...
# 1  2723485  I made a program in Python and now I whant to ...
# 2  5088821  I have a string (with multiple lines) which co...
# 3  8121789  In my python code i want to pattern match a st...
# 4  9815095  I use the regex [,;\s]+ to split a comma, spac...
#
#                                                Title                     Tags
# 0  Find all Chinese text in a string using Python...     <python><regex><cjk>
# 1                             Python Regex To VB.net  <python><vb.net><regex>
# 2  how to match lines between pattern using re mo...          <python><regex>
# 3  Pattern Match a string for atleast two consecu...          <python><regex>
# 4  split a comma, space, or semicolon separated s...          <python><regex>

# %%
# save the processed data to a csv file
data.to_csv('data/Test/regex.csv', index=False)
